# %%
import numpy
import matplotlib.pyplot
import random as random
import scipy.stats

def initialize_setting():
    # float values formating
    float_formatter = "{:.3f}".format
    numpy.set_printoptions(formatter={'float_kind':float_formatter})
    
initialize_setting()

# %%
def core_function(input_data, post_process_hist_output = False):
    binsRange = (numpy.floor(input_data.min()), numpy.ceil(input_data.max()))
    densityFlag = True
    bins_count = 10
    print("Inputs to numpy.histogram()")
    print("              a = ", input_data)
    print("          range = ", binsRange)
    print("        density = ", densityFlag)
    print("     bins_count = ", bins_count)
    print("")
    
    hist_values, bin_edges = numpy.histogram(a = input_data, density=densityFlag, range=binsRange, bins=bins_count)
    
    print("post_process_hist_output = ", post_process_hist_output)
    
    if(post_process_hist_output):
        hist_values = hist_values/sum(hist_values)
        
    print("Output of numpy.histogram()")
    print("    hist_values = ", hist_values)
    print("      bin_edges = ", bin_edges)
    print("")
    
    print("Inputs to numpy.cumsum()")
    print("              a = ", hist_values)
    print("")
    cdf = numpy.cumsum(hist_values)
    print("Output of numpy.cumsum()")
    print("            cdf = ", cdf)
    print("")
    
    print("sum(hist_values) = ",  sum(hist_values), end="\n\n")
    
    matplotlib.pyplot.grid()
    matplotlib.pyplot.title("Histogram (green), normal dist plot(yellow), CDF(blue)")
    matplotlib.pyplot.xlabel("Random numbers in normal distribution")
    matplotlib.pyplot.ylabel("Probability")
    matplotlib.pyplot.plot(bin_edges[1:], hist_values, 'g')
    matplotlib.pyplot.plot(bin_edges[1:], cdf)

def plotNormalDistribution(input_data, mu, sigma):
    pdata = numpy.sort(input_data)
    matplotlib.pyplot.plot(pdata, scipy.stats.norm.pdf(pdata, mu, sigma), 'y')

# %%
def example_zero_to_ten_data_range():
    matplotlib.pyplot.figure()
    mu, sigma = 5, 1 # mean and standard deviation
    input_data_length = 9999
    data = numpy.random.normal(mu, sigma, input_data_length)

    '''
    As the random number are generated using normal dist, it is very unlikely to have number greater than 9 and
    less than 1.
    If that happens then range input to numpy.histogram() will be like (1, 9)
    If the range input to numpy.histogram() is not (0, 10) then it wont generate unity bins which is 
    must for this demonstration
    '''
    data = numpy.append(data, 9.00001) 
    data = numpy.append(data, 0.00001) 
    core_function(data)

    plotNormalDistribution(data, mu, sigma)

example_zero_to_ten_data_range()
# Out:
# Inputs to numpy.histogram()
#               a =  [6.176 6.689 4.952 ... 6.010 9.000 0.000]
#           range =  (0.0, 10.0)
#         density =  True
#      bins_count =  10
#
# post_process_hist_output =  False
# Output of numpy.histogram()
#     hist_values =  [0.000 0.001 0.021 0.139 0.341 0.336 0.137 0.023 0.001 0.000]
#       bin_edges =  [0.000 1.000 2.000 3.000 4.000 5.000 6.000 7.000 8.000 9.000 10.000]
#
# Inputs to numpy.cumsum()
#               a =  [0.000 0.001 0.021 0.139 0.341 0.336 0.137 0.023 0.001 0.000]
#
# Output of numpy.cumsum()
#             cdf =  [0.000 0.001 0.023 0.162 0.503 0.839 0.976 0.999 1.000 1.000]
#
# sum(hist_values) =  1.0

# %%
def example_data_1():
    matplotlib.pyplot.figure()
    mu, sigma = 0.0, 1 # mean and standard deviation
    input_data_length = 9999
    data = numpy.random.normal(mu, sigma, input_data_length)

    core_function(data, True)

    plotNormalDistribution(data, mu, sigma)


example_data_1()
# Out:
# Inputs to numpy.histogram()
#               a =  [-1.036 -0.320 1.553 ... -0.997 1.474 0.640]
#           range =  (-4.0, 5.0)
#         density =  True
#      bins_count =  10
#
# post_process_hist_output =  True
# Output of numpy.histogram()
#     hist_values =  [0.001 0.011 0.082 0.251 0.344 0.232 0.070 0.009 0.001 0.000]
#       bin_edges =  [-4.000 -3.100 -2.200 -1.300 -0.400 0.500 1.400 2.300 3.200 4.100 5.000]
#
# Inputs to numpy.cumsum()
#               a =  [0.001 0.011 0.082 0.251 0.344 0.232 0.070 0.009 0.001 0.000]
#
# Output of numpy.cumsum()
#             cdf =  [0.001 0.012 0.094 0.345 0.689 0.920 0.990 0.999 1.000 1.000]
#
# sum(hist_values) =  0.9999999999999999

# %%
def example():
    matplotlib.pyplot.figure()
    input_data_length = 50
    data = numpy.random.random_sample(input_data_length)
    core_function(data, True)
    
example()
# Out:
# Inputs to numpy.histogram()
#               a =  [0.083 0.064 0.631 0.857 0.385 0.289 0.254 0.011 0.835 0.818 0.352 0.290
#  0.731 0.924 0.472 0.617 0.351 0.449 0.323 0.487 0.741 0.033 0.562 0.749
#  0.223 0.240 0.221 0.226 0.396 0.290 0.617 0.605 0.389 0.254 0.157 0.473
#  0.854 0.842 0.417 0.063 0.169 0.556 0.038 0.236 0.640 0.667 0.079 0.211
#  0.717 0.741]
#           range =  (0.0, 1.0)
#         density =  True
#      bins_count =  10
#
# post_process_hist_output =  True
# Output of numpy.histogram()
#     hist_values =  [0.140 0.040 0.220 0.120 0.100 0.040 0.120 0.100 0.100 0.020]
#       bin_edges =  [0.000 0.100 0.200 0.300 0.400 0.500 0.600 0.700 0.800 0.900 1.000]
#
# Inputs to numpy.cumsum()
#               a =  [0.140 0.040 0.220 0.120 0.100 0.040 0.120 0.100 0.100 0.020]
#
# Output of numpy.cumsum()
#             cdf =  [0.140 0.180 0.400 0.520 0.620 0.660 0.780 0.880 0.980 1.000]
#
# sum(hist_values) =  1.0000000000000002
